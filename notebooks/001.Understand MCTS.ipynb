# %%
import gym
import numpy as np
import time
import pachi_py

from gym.envs.board_game.go import _coord_to_action, GoState
SEED = 0
np.random.seed(SEED)

# %% [markdown]
# Let's see if we can beat the gym environment using only MCTS
#
# If we seed the gym environment, we can recreate the game state

# %% [markdown]
# ### In each iteration of MCTS, there are four steps
#
# 1. Selection
# 1. Expansion
# 1. Simulation
# 1. Backpropagation

# %%
env_id = 'Go9x9-v0'
def get_env():
    env = gym.make(env_id)
    env.seed(SEED)
    env.reset()
    return env

# %%
def get_legal_actions(state):
    actions = [_coord_to_action(state.board, c) for c in state.board.get_legal_coords(state.color)]
    return actions

# %%
def fast_sim(state):
    
    state = GoState(state.board.clone(), state.color)
    og_player = state.color
    
    actions = dict()
    actions[pachi_py.BLACK] = []
    actions[pachi_py.WHITE] = []
    
    while not state.board.is_terminal:
        player = state.color   
        a = np.random.choice(state.board.get_legal_coords(player))
        a = _coord_to_action(state.board, a)
        state = state.act(a)
        actions[player].append(a)
        # resign is the end of the game
        if a==pachi_py.RESIGN_COORD:
            break
    
    # Score with respect to player
    score = np.sign(state.board.official_score)
    if og_player == pachi_py.BLACK:
        score = np.negative(score)
    
    # Resignation is always loosing
    if a == pachi_py.RESIGN_COORD:
        if player == og_player:
            score = -1
        else:
            score = 1

    return score, actions

# %%
class Node():
    def __init__(self, state, parent=None):
        
        self.state = GoState(state.board.clone(), state.color)
        self.unexpanded = get_legal_actions(self.state)
        self.parent = parent
        self.child = dict() # key: action
        self.r = 0.
        self.n = 0.
        
    def select(self):
        actions = []
        ucbs = []
        for a, n in self.child.items():
            actions.append(a)
            ucbs.append(n.get_ucb())
        i = np.argmax(ucbs)
        a = actions[i]
        return self.child[a]
    
    def get_ucb(self):
        assert self.n > 0
        return self.r / self.n + 2 * np.sqrt(np.log(self.parent.n)/self.n)
        
    def expand(self):
        assert self.expandable
        action = self.unexpanded[0]
        self.child[action] = Node(self.state, self)
        self.unexpanded.remove(action)
        return self.child[action]
    
    def update(self, r):
        self.n += 1
        self.r +=r
        
    @property
    def n_child(self):
        return len(self.child)
    
    @property
    def expandable(self):
        if len(self.unexpanded) > 0:
            return True
        else:
            return False

# %%
def mcts(root_node):
    current_node = root_node
    
    # Selection
    while not current_node.expandable:
        current_node = current_node.select()
        
    # Expansion
    current_node = current_node.expand()
    
    # Simulate
    r, _ = fast_sim(current_node.state)
    current_node.update(r)
    
    # backprop
    while current_node.parent is not None:
        r = -r
        current_node = current_node.parent
        current_node.update(r)

# %% [markdown]
# # Test

# %%
env = get_env()
root_node = Node(env.state, None)
for i in range(10000):
    mcts(root_node)

# %%
# for k, v in root_node.child.items():
#     print('ACTION: {:2} VISITS: {:3.0f} REWARD: {:3.0f}'.format(k, v.n, v.r))
# Out:
# ACTION:  0 VISITS: 130 REWARD:  -2
# ACTION:  1 VISITS: 145 REWARD:   2
# ACTION:  2 VISITS:  76 REWARD: -14
# ACTION:  3 VISITS: 138 REWARD:   0
# ACTION:  4 VISITS:  94 REWARD: -11
# ACTION: 66 VISITS:  95 REWARD: -10
# ACTION: 67 VISITS: 209 REWARD:  20
# ACTION: 68 VISITS: 130 REWARD:  -2
# ACTION: 69 VISITS: 166 REWARD:   7
# ACTION: 70 VISITS: 213 REWARD:  21
# ACTION: 71 VISITS: 194 REWARD:  16
# ACTION: 72 VISITS:  86 REWARD: -12
# ACTION: 73 VISITS: 109 REWARD:  -8
# ACTION: 74 VISITS: 178 REWARD:  11
# ACTION: 75 VISITS: 174 REWARD:   9
# ACTION: 76 VISITS: 214 REWARD:  22
# ACTION: 77 VISITS:  60 REWARD: -16
# ACTION: 78 VISITS: 118 REWARD:  -5
# ACTION: 79 VISITS:  86 REWARD: -12
# ACTION: 80 VISITS: 156 REWARD:   4
# ACTION: 81 VISITS: 160 REWARD:   6

# %%
a = root_node.child[0].child[33]
for k, v in a.child.items():
    print('ACTION: {:2} VISITS: {:3.0f} REWARD: {:3.0f}'.format(k, v.n, v.r))
# Out:
# ACTION: 81 VISITS:   1 REWARD:   1

# %% [markdown]
# # Play a Game

# %%
env = get_env()
done = False
while not done:
    root_node = Node(env.state, None)
    tic = time.time()
    for i in range(8000):
        mcts(root_node)
    toc = time.time() - tic
    print('DECISION TIME: {:.1f}s'.format(toc))
        
    actions = []
    actions_visits = []
    actions_value = []

    for k, v in root_node.child.items():
        actions.append(k)
        actions_visits.append(v.n)
        actions_value.append(v.r)
    max_n = np.argmax(actions_visits)
    max_r = np.argmax(actions_value)
    print('Most Visited:\t A:{} F:{} V:{}'.format(actions[max_n], actions_visits[max_n], actions_value[max_n]))
    print('Highest Value:\t A:{} F:{} V:{}'.format(actions[max_r], actions_visits[max_r], actions_value[max_r]))
    a = actions[max_n]
    ob, r, done, info = env.step(a)
    env.render()
# Out:
# DECISION TIME: 24.1s
# Most Visited:	 A:60 F:195.0 V:28.0
# Highest Value:	 A:60 F:195.0 V:28.0
# To play: black
# Move:   2  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . . . |
#   8 | . . . . . . . . . |
#   7 | . . . . . . . . . |
#   6 | . . . O). . . . . |
#   5 | . . . . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . . . X . . |
#   2 | . . . . . . . . . |
#   1 | . . . . . . . . . |
#     +-------------------+
# DECISION TIME: 23.9s
# Most Visited:	 A:77 F:208.0 V:35.0
# Highest Value:	 A:77 F:208.0 V:35.0
# To play: black
# Move:   4  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . . . |
#   8 | . . . . . . . . . |
#   7 | . . . . . . . . . |
#   6 | . . . O . . . . . |
#   5 | . . . . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . . . X . . |
#   2 | . . . . . O). . . |
#   1 | . . . . . X . . . |
#     +-------------------+
# DECISION TIME: 24.1s
# Most Visited:	 A:73 F:215.0 V:38.0
# Highest Value:	 A:73 F:215.0 V:38.0
# To play: black
# Move:   6  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . . . |
#   8 | . O). . . . . . . |
#   7 | . . . . . . . . . |
#   6 | . . . O . . . . . |
#   5 | . . . . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . . . X . . |
#   2 | . . . . . O . . . |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 24.2s
# Most Visited:	 A:20 F:186.0 V:29.0
# Highest Value:	 A:20 F:186.0 V:29.0
# To play: black
# Move:   8  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . . . |
#   8 | . O . . . . . . . |
#   7 | . . X . . . . . . |
#   6 | . . . O . . . . . |
#   5 | . . O). . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . . . X . . |
#   2 | . . . . . O . . . |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 22.6s
# Most Visited:	 A:58 F:206.0 V:39.0
# Highest Value:	 A:58 F:206.0 V:39.0
# To play: black
# Move:  10  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . . . |
#   8 | . O . . . . . . . |
#   7 | . . X . . . . . . |
#   6 | . . . O . . . . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . X O)X . . |
#   2 | . . . . . O . . . |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 22.5s
# Most Visited:	 A:7 F:186.0 V:29.0
# Highest Value:	 A:7 F:186.0 V:29.0
# To play: black
# Move:  12  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | . . . . . . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O). . . . . |
#   6 | . . . O . . . . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . X O X . . |
#   2 | . . . . . O . . . |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 22.1s
# Most Visited:	 A:0 F:161.0 V:26.0
# Highest Value:	 A:0 F:161.0 V:26.0
# To play: black
# Move:  14  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . . . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O . . . . . |
#   6 | . . . O . . . . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . . . . |
#   3 | . . . . X O X . . |
#   2 | . . . . . O . O). |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 22.1s
# Most Visited:	 A:23 F:169.0 V:19.0
# Highest Value:	 A:23 F:169.0 V:19.0
# To play: black
# Move:  16  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . . . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O . X . . . |
#   6 | . . . O . . . . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . O). . |
#   3 | . . . . X O X . . |
#   2 | . . . . . O . O . |
#   1 | . X . . . X . . . |
#     +-------------------+
# DECISION TIME: 21.5s
# Most Visited:	 A:76 F:177.0 V:21.0
# Highest Value:	 A:76 F:177.0 V:21.0
# To play: black
# Move:  18  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . . . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O . X . . . |
#   6 | . . . O . . . . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . O . . |
#   3 | . . . . X O X O). |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 22.1s
# Most Visited:	 A:52 F:184.0 V:22.0
# Highest Value:	 A:52 F:184.0 V:22.0
# To play: black
# Move:  20  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . . . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O . X . . . |
#   6 | . . . O . O). . . |
#   5 | . . O . . . . . . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O . |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 20.9s
# Most Visited:	 A:4 F:183.0 V:15.0
# Highest Value:	 A:4 F:183.0 V:15.0
# To play: black
# Move:  22  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X . . X . |
#   8 | . O . . . . . . . |
#   7 | . . X O . X . . . |
#   6 | . . . O . O . . . |
#   5 | . . O . . . . O). |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O . |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 20.7s
# Most Visited:	 A:62 F:187.0 V:4.0
# Highest Value:	 A:62 F:187.0 V:4.0
# To play: black
# Move:  24  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X . . X . |
#   8 | . O . . . O). . . |
#   7 | . . X O . X . . . |
#   6 | . . . O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O X |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 20.6s
# Most Visited:	 A:11 F:181.0 V:2.0
# Highest Value:	 A:11 F:181.0 V:2.0
# To play: black
# Move:  26  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X . . X . |
#   8 | . O X . . O . . . |
#   7 | . . X O O)X . . . |
#   6 | . . . O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O X |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 22.4s
# Most Visited:	 A:25 F:201.0 V:-3.0
# Highest Value:	 A:25 F:201.0 V:-3.0
# To play: black
# Move:  28  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X O). X . |
#   8 | . O X . . O . . . |
#   7 | . . X O O X . X . |
#   6 | . . . O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O X |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 20.9s
# Most Visited:	 A:18 F:218.0 V:-6.0
# Highest Value:	 A:18 F:218.0 V:-6.0
# To play: black
# Move:  30  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X O . X . |
#   8 | . O X . . O . . . |
#   7 | X . X O O X . X . |
#   6 | . . O)O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O X |
#   2 | . . . . . O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 20.2s
# Most Visited:	 A:8 F:196.0 V:-20.0
# Highest Value:	 A:8 F:196.0 V:-20.0
# To play: black
# Move:  32  Komi: 0.0  Handicap: 0  Captures B: 0 W: 0
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X O . X X |
#   8 | . O X . . O . . . |
#   7 | X . X O O X . X . |
#   6 | . . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O X . |
#   3 | . . . . X O X O X |
#   2 | . . . . O)O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 19.8s
# Most Visited:	 A:27 F:196.0 V:-34.0
# Highest Value:	 A:27 F:196.0 V:-34.0
# To play: black
# Move:  34  Komi: 0.0  Handicap: 0  Captures B: 0 W: 1
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X O . X X |
#   8 | . O X . . O . . . |
#   7 | X . X O O X . X . |
#   6 | X . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O . O)|
#   3 | . . . . X O X O X |
#   2 | . . . . O O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 19.1s
# Most Visited:	 A:55 F:198.0 V:-49.0
# Highest Value:	 A:2 F:143.0 V:-46.0
# To play: black
# Move:  36  Komi: 0.0  Handicap: 0  Captures B: 0 W: 1
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . . X O . X X |
#   8 | . O X . O)O . . . |
#   7 | X . X O O X . X . |
#   6 | X . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O . O |
#   3 | . X . . X O X O X |
#   2 | . . . . O O . O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 17.7s
# Most Visited:	 A:3 F:206.0 V:-59.0
# Highest Value:	 A:28 F:142.0 V:-53.0
# To play: black
# Move:  38  Komi: 0.0  Handicap: 0  Captures B: 0 W: 2
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O . X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O X . X . |
#   6 | X . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O . O |
#   3 | . X . . X O . O X |
#   2 | . . . . O O O)O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 17.2s
# Most Visited:	 A:6 F:220.0 V:-75.0
# Highest Value:	 A:80 F:146.0 V:-63.0
# To play: black
# Move:  40  Komi: 0.0  Handicap: 0  Captures B: 0 W: 3
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O)X . |
#   6 | X . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . . O . O |
#   3 | . X . . X O . O X |
#   2 | . . . . O O O O . |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 17.5s
# Most Visited:	 A:50 F:233.0 V:-90.0
# Highest Value:	 A:80 F:169.0 V:-77.0
# To play: black
# Move:  42  Komi: 0.0  Handicap: 0  Captures B: 0 W: 4
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O X . |
#   6 | X . O O . O . . . |
#   5 | . . O . . . . O . |
#   4 | . . . . . X O . O |
#   3 | . X . . X O . O . |
#   2 | . . . . O O O O O)|
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 19.2s
# Most Visited:	 A:31 F:232.0 V:-99.0
# Highest Value:	 A:36 F:169.0 V:-84.0
# To play: black
# Move:  44  Komi: 0.0  Handicap: 0  Captures B: 0 W: 5
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O X . |
#   6 | X . O O . O . . . |
#   5 | . . O . O). . O . |
#   4 | . . . . . X O . O |
#   3 | . X . . X O . O . |
#   2 | . . . . O O O O O |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 16.5s
# Most Visited:	 A:41 F:252.0 V:-116.0
# Highest Value:	 A:39 F:172.0 V:-93.0
# To play: black
# Move:  46  Komi: 0.0  Handicap: 0  Captures B: 0 W: 5
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O X . |
#   6 | X . O O . O . . . |
#   5 | . . O . O X . O . |
#   4 | . . . . O)X O . O |
#   3 | . X . . X O . O . |
#   2 | . . . . O O O O O |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 16.3s
# Most Visited:	 A:48 F:254.0 V:-132.0
# Highest Value:	 A:19 F:187.0 V:-109.0
# To play: black
# Move:  48  Komi: 0.0  Handicap: 0  Captures B: 0 W: 6
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O X . |
#   6 | X . O O . O . . . |
#   5 | . . O . O X . O . |
#   4 | . . . X O X O . O |
#   3 | . X . O). O . O . |
#   2 | . . . . O O O O O |
#   1 | . X . . X X . . . |
#     +-------------------+
# DECISION TIME: 16.5s
# Most Visited:	 A:80 F:282.0 V:-162.0
# Highest Value:	 A:28 F:195.0 V:-126.0
# To play: black
# Move:  50  Komi: 0.0  Handicap: 0  Captures B: 0 W: 7
#       A B C D E F G H J
#     +-------------------+
#   9 | X . . X X O X X X |
#   8 | . O X . O O . . . |
#   7 | X . X O O . O X . |
#   6 | X . O O . O . . . |
#   5 | . . O . O X . O . |
#   4 | . . . X O X O . O |
#   3 | . X . O . O . O . |
#   2 | . . . . O O O O O |
#   1 | . X . . X X . O). |
#     +-------------------+
# DECISION TIME: 16.3s
# Most Visited:	 A:78 F:275.0 V:-170.0
# Highest Value:	 A:75 F:219.0 V:-145.0
# To play: black
# Move:  52  Komi: 0.0  Handicap: 0  Captures B: 0 W: 10
#       A B C D E F G H J
#     +-------------------+
#   9 | X .
# Highest Value:	 A:34 F:279.0 V:-223.0
# To play: black
# Move:  64  Komi: 0.0  Handicap: 0  Captures B: 0 W: 13
#       A B C D E F G H J
#     +-------------------+
#   9 | X O X X X O X X X |
#   8 | . O X . O O . X . |
#   7 | X X X O O . O X . |
#   6 | X . O O . O . . O |
#   5 | . . O O)O X . O . |
#   4 | . . O . O X O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.6s
# Most Visited:	 A:12 F:2528.0 V:1502.0
# Highest Value:	 A:12 F:2528.0 V:1502.0
# To play: black
# Move:  66  Komi: 0.0  Handicap: 0  Captures B: 0 W: 15
#       A B C D E F G H J
#     +-------------------+
#   9 | X O X X X O X X X |
#   8 | . O X X O O . X . |
#   7 | X X X O O . O X . |
#   6 | X . O O . O . . O |
#   5 | . . O O O . O)O . |
#   4 | . . O . O . O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 14.2s
# Most Visited:	 A:37 F:2938.0 V:1894.0
# Highest Value:	 A:37 F:2938.0 V:1894.0
# To play: black
# Move:  68  Komi: 0.0  Handicap: 0  Captures B: 0 W: 15
#       A B C D E F G H J
#     +-------------------+
#   9 | X O X X X O X X X |
#   8 | . O X X O O . X . |
#   7 | X X X O O . O X . |
#   6 | X . O O . O . . O |
#   5 | . X O O O . O O . |
#   4 | . O)O . O . O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.3s
# Most Visited:	 A:9 F:3924.0 V:2827.0
# Highest Value:	 A:9 F:3924.0 V:2827.0
# To play: black
# Move:  70  Komi: 0.0  Handicap: 0  Captures B: 2 W: 15
#       A B C D E F G H J
#     +-------------------+
#   9 | X . X X X O X X X |
#   8 | X . X X O O . X . |
#   7 | X X X O O . O X . |
#   6 | X O)O O . O . . O |
#   5 | . X O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.1s
# Most Visited:	 A:10 F:3532.0 V:2537.0
# Highest Value:	 A:10 F:3532.0 V:2537.0
# To play: black
# Move:  72  Komi: 0.0  Handicap: 0  Captures B: 2 W: 16
#       A B C D E F G H J
#     +-------------------+
#   9 | X . X X X O X X X |
#   8 | X X X X O O . X . |
#   7 | X X X O O . O X . |
#   6 | X O O O . O . . O |
#   5 | O). O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.5s
# Most Visited:	 A:33 F:5346.0 V:755.0
# Highest Value:	 A:33 F:5346.0 V:755.0
# To play: black
# Move:  74  Komi: 0.0  Handicap: 0  Captures B: 2 W: 28
#       A B C D E F G H J
#     +-------------------+
#   9 | . O). . . O X X X |
#   8 | . . . . O O . X . |
#   7 | . . . O O . O X . |
#   6 | . O O O . O X . O |
#   5 | O . O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | . X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | . X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.7s
# Most Visited:	 A:72 F:358.0 V:-254.0
# Highest Value:	 A:45 F:262.0 V:-200.0
# To play: black
# Move:  76  Komi: 0.0  Handicap: 0  Captures B: 2 W: 28
#       A B C D E F G H J
#     +-------------------+
#   9 | . O . . . O X X X |
#   8 | . . . . O O . X . |
#   7 | . . . O O . O X . |
#   6 | . O O O . O X . O |
#   5 | O . O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | O)X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | X X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.4s
# Most Visited:	 A:20 F:386.0 V:-284.0
# Highest Value:	 A:0 F:308.0 V:-238.0
# To play: black
# Move:  78  Komi: 0.0  Handicap: 0  Captures B: 2 W: 28
#       A B C D E F G H J
#     +-------------------+
#   9 | . O . . . O X X X |
#   8 | . . . . O O . X . |
#   7 | . O)X O O . O X . |
#   6 | . O O O . O X . O |
#   5 | O . O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | O X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | X X . O . O . O . |
#     +-------------------+
# DECISION TIME: 12.7s
# Most Visited:	 A:18 F:1256.0 V:344.0
# Highest Value:	 A:18 F:1256.0 V:344.0
# To play: black
# Move:  80  Komi: 0.0  Handicap: 0  Captures B: 2 W: 28
#       A B C D E F G H J
#     +-------------------+
#   9 | . O . . . O X X X |
#   8 | O). . . O O . X . |
#   7 | X O X O O . O X . |
#   6 | . O O O . O X . O |
#   5 | O . O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | O X O O . O . O . |
#   2 | . X . . O O O O O |
#   1 | X X . O . O . O . |
#     +-------------------+
# DECISION TIME: 13.1s
# Most Visited:	 A:66 F:4313.0 V:2960.0
# Highest Value:	 A:66 F:4313.0 V:2960.0
# To play: black
# Move:  82  Komi: 0.0  Handicap: 0  Captures B: 2 W: 29
#       A B C D E F G H J
#     +-------------------+
#   9 | . O . . . O X X X |
#   8 | O . . . O O . X . |
#   7 | X O X O O . O X . |
#   6 | . O O O . O X . O |
#   5 | O . O O O . O O . |
#   4 | . O O . O . O . O |
#   3 | O X O O . O . O . |
#   2 | . X O). O O O O O |
#   1 | X X . O . O . O . |
#     +-------------------+

# %%
if r > 0:
    print('WIN')
elif r < 0:
    print('LOST')
else:
    print('DRAW')

# %%
env.state.board.official_score

# %% [markdown]
# # Closing Thoughts

# %% [markdown]
# * When expanding a new node, parallelisation can be used to increase speed. E.g. expand all nodes at the same time.
# * Tree policy enhancements such as AMAF and RAVE would be more suitable to Go.
# * The simulation/rollout phase would be more accurate if we understand the policy of the enemy. E.g. a neural network that predicts enemy moves.
# * MCTS along is not enought as the game of Go has a very large search space
